# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/clead_google_playstore_data")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  day  \
# 10835          Education   2017-07-25                1.48        4.1    25
# 10836          Education   2018-07-06                 1.0        4.1     6
# 10837            Medical   2017-01-20                 1.0        2.2    20
# 10838  Books & Reference   2015-01-19  Varies with device         NaN   19
# 10839          Lifestyle   2018-07-25  Varies with device         NaN   25
#
#        month  year
# 10835      7  2017
# 10836      7  2018
# 10837      1  2017
# 10838      1  2015
# 10839      7  2018

# %%
df.sample(9)
# Out:
#                                                     App             Category  \
# 6470                                          bm-Events               SOCIAL
# 2617                     MeetMe: Chat & Meet New People               SOCIAL
# 10510                                  Motocross Mayhem                 GAME
# 1925   Sniper 3D Gun Shooter: Free Shooting Games - FPS                 GAME
# 8983                                   News: DW Español   NEWS_AND_MAGAZINES
# 6714                      iPlayIT for YouTube VR Player        VIDEO_PLAYERS
# 7689                            iTooch Mathématiques CP               FAMILY
# 5159                                               Ah !               FAMILY
# 8204                                   DB Streckenagent  MAPS_AND_NAVIGATION
#
#        Rating  Reviews     Size   Installs  Type  Price Content Rating  \
# 6470      NaN        0   8100.0         10  Free    0.0           Teen
# 2617      4.2  1259894  76000.0   50000000  Free    0.0     Mature 17+
# 10510     3.8    35171  45000.0    1000000  Free    0.0       Everyone
# 1925      4.6  7674252      NaN  100000000  Free    0.0     Mature 17+
# 8983      4.3       25   6300.0       1000  Free    0.0       Everyone
# 6714      4.3     5879      NaN    1000000  Free    0.0           Teen
# 7689      4.3     1018  35000.0     100000  Free    0.0       Everyone
# 5159      NaN        3  22000.0         50  Free    0.0       Everyone
# 8204      3.9     4569   7500.0     500000  Free    0.0       Everyone
#
#                         Genres Last Updated         Current Ver Android Ver  \
# 6470                    Social   2016-11-01               1.1.1        4.4
# 2617                    Social   2018-08-03  Varies with device        4.1
# 10510                   Racing   2014-02-11                 1.2        2.3
# 1925                    Action   2018-08-02  Varies with device         NaN
# 8983          News & Magazines   2018-04-26                 1.0        4.1
# 6714   Video Players & Editors   2018-06-12  Varies with device        4.1
# 7689       Education;Education   2017-06-28               4.6.2      4.0.3
# 5159             Entertainment   2017-12-27               1.1.2        5.0
# 8204         Maps & Navigation   2017-12-22         2.1.10 (49)        4.0
#
#        day  month  year
# 6470     1     11  2016
# 2617     3      8  2018
# 10510   11      2  2014
# 1925     2      8  2018
# 8983    26      4  2018
# 6714    12      6  2018
# 7689    28      6  2017
# 5159    27     12  2017
# 8204    22     12  2017

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
df[["Reviews","Rating"]]
# Out:
#        Reviews  Rating
# 0          159     4.1
# 1          967     3.9
# 2        87510     4.7
# 3       215644     4.5
# 4          967     4.3
# ...        ...     ...
# 10835       38     4.5
# 10836        4     5.0
# 10837        3     NaN
# 10838      114     4.5
# 10839   398307     4.5
#
# [10840 rows x 2 columns]

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
#        Reviews     Size   Installs  Type  Price Content Rating        Genres  \
# 229      80805      NaN    5000000  Free    0.0       Everyone      Business
# 236     159872      NaN   10000000  Free    0.0       Everyone      Business
# 239      70991      NaN    5000000  Free    0.0       Everyone      Business
# 256      31614  37000.0   10000000  Free    0.0       Everyone      Business
# 261       6989      NaN    1000000  Free    0.0       Everyone      Business
# ...        ...      ...        ...   ...    ...            ...           ...
# 8643    404610      NaN   10000000  Free    0.0       Everyone  Productivity
# 8654     25370      NaN    1000000  Free    0.0       Everyone  Productivity
# 8658   2401017      NaN  100000000  Free    0.0       Everyone  Productivity
# 10049      123  86000.0      10000  Free    0.0       Everyone       Medical
# 10767       63  24000.0      10000  Free    0.0       Everyone       Medical
#
#       Last Updated         Current Ver Android Ver  day  month  year
# 229     2018-02-26  Varies with device      4.0.3    26      2  2018
# 236     2018-07-31  Varies with device         NaN   31      7  2018
# 239     2018-07-24    2.19.0.204537701        4.4    24      7  2018
# 256     2018-07-20      4.1.28165.0716        4.0    20      7  2018
# 261     2018-07-16           4.3.0.508        4.4    16      7  2018
# ...            ...                 ...         ...  ...    ...   ...
# 8643    2018-04-06  Varies with device         NaN    6      4  2018
# 8654    2018-08-06  Varies with device         NaN    6      8  2018
# 8658    2018-06-27  Varies with device         NaN   27      6  2018
# 10049   2018-06-01              0.6.88        5.0     1      6  2018
# 10767   2018-06-22               2.3.1        5.0    22      6  2018
#
# [483 rows x 16 columns]

# %%
df[df.duplicated("Reviews")]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# 4          967   2800.0    100000  Free    0.0       Everyone
# 57         129  54000.0    100000  Free    0.0       Everyone
# 126        654   7400.0    100000  Free    0.0           Teen
# 134         30   9900.0     10000  Free    0.0     Mature 17+
# 156        967   6700.0    500000  Free    0.0       Everyone
# ...        ...      ...       ...   ...    ...            ...
# 10834        0   9600.0        10  Free    0.0       Everyone
# 10835       38  53000.0      5000  Free    0.0       Everyone
# 10836        4   3600.0       100  Free    0.0       Everyone
# 10837        3   9500.0      1000  Free    0.0       Everyone
# 10838      114      NaN      1000  Free    0.0     Mature 17+
#
#                         Genres Last Updated         Current Ver Android Ver  \
# 4      Art & Design;Creativity   2018-06-20                 1.1        4.4
# 57             Auto & Vehicles   2018-07-26                 3.0        4.1
# 126                     Beauty   2018-07-17                1.15        4.1
# 134                     Beauty   2018-01-24                 3.0        3.0
# 156          Books & Reference   2018-08-04               1.1.6      4.0.3
# ...                        ...          ...                 ...         ...
# 10834                 Business   2016-09-29               1.1.5        4.0
# 10835                Education   2017-07-25                1.48        4.1
# 10836                Education   2018-07-06                 1.0        4.1
# 10837                  Medical   2017-01-20                 1.0        2.2
# 10838        Books & Reference   2015-01-19  Varies with device         NaN
#
#        day  month  year
# 4       20      6  2018
# 57      26      7  2018
# 126     17      7  2018
# 134     24      1  2018
# 156      4      8  2018
# ...    ...    ...   ...
# 10834   29      9  2016
# 10835   25      7  2017
# 10836    6      7  2018
# 10837   20      1  2017
# 10838   19      1  2015
#
# [4839 rows x 16 columns]

# %%
df=df.drop_duplicates(subset=["App"],keep="first")

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  day             9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype != "O"]

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
categorical_features ## ctegoric ---plot a countplot graph
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df["Type"].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
df["Type"].value_counts(normalize=True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("#################################################")
# Out:
# App:TEKKEN™                          0.010353
# Alzashop.com                     0.010353
# West Central Ag                  0.010353
# CB Pay                           0.010353
# FX LITE BO                       0.010353
#                                    ...
# LokLok: Draw on a Lock Screen    0.010353
# SenseView BT Zephyr Sensor       0.010353
# Elmo Calls by Sesame Street      0.010353
# Windguru Lite                    0.010353
# AJ-COMICS                        0.010353
# Name: App, Length: 9659, dtype: float64
# #################################################
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# LIFESTYLE               3.820271
# FINANCE                 3.571798
# SPORTS                  3.364738
# COMMUNICATION           3.261207
# HEALTH_AND_FITNESS      2.981675
# PHOTOGRAPHY             2.909204
# NEWS_AND_MAGAZINES      2.629672
# SOCIAL                  2.474376
# BOOKS_AND_REFERENCE     2.298375
# TRAVEL_AND_LOCAL        2.267315
# SHOPPING                2.091314
# DATING                  1.770370
# VIDEO_PLAYERS           1.687545
# MAPS_AND_NAVIGATION     1.356248
# EDUCATION               1.232012
# FOOD_AND_DRINK          1.159540
# ENTERTAINMENT           1.056010
# AUTO_AND_VEHICLES       0.880008
# LIBRARIES_AND_DEMO      0.869655
# WEATHER                 0.817890
# HOUSE_AND_HOME          0.766125
# EVENTS                  0.662594
# ART_AND_DESIGN          0.662594
# PARENTING               0.621182
# COMICS                  0.579770
# BEAUTY                  0.548711
# Name: Category, dtype: float64
# #################################################
# Type:Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64
# #################################################
# Content Rating:Everyone           81.820064
# Teen               10.725748
# Mature 17+          4.068744
# Everyone 10+        3.333678
# Adults only 18+     0.031059
# Unrated             0.020706
# Name: Content Rating, dtype: float64
# #################################################
# Genres:Tools                       8.551610
# Entertainment               5.808055
# Education                   5.280050
# Business                    4.348276
# Medical                     4.089450
#                               ...
# Comics;Creativity           0.010353
# Communication;Creativity    0.010353
# Adventure;Education         0.010353
# Entertainment;Education     0.010353
# Board;Pretend Play          0.010353
# Name: Genres, Length: 118, dtype: float64
# #################################################
# Last Updated:2018-08-03    2.608966
# 2018-08-02    2.381199
# 2018-08-01    2.163785
# 2018-07-31    2.112020
# 2018-07-30    1.656486
#                 ...
# 2012-09-19    0.010353
# 2015-07-14    0.010353
# 2014-06-09    0.010353
# 2015-10-01    0.010353
# 2014-04-11    0.010353
# Name: Last Updated, Length: 1377, dtype: float64
# #################################################
# Current Ver:Varies with device    10.931510
# 1.0                    8.278935
# 1.1                    2.694021
# 1.2                    1.823645
# 2.0                    1.543881
#                         ...
# 11.04                  0.010362
# v2                     0.010362
# 5.7.8                  0.010362
# 1.0.606877             0.010362
# 18.7                   0.010362
# Name: Current Ver, Length: 2817, dtype: float64
# #################################################
# Android Ver:4.1              25.406715
# 4.0.3            16.095535
# 4.0              14.826353
# 4.4               9.438099
# 2.3               7.107419
# 5.0               5.907465
# 4.2               4.292143
# 2.3.3             3.149879
# 2.2               2.757586
# 3.0               2.665282
# 4.3               2.549902
# 2.1               1.534556
# 1.6               1.338410
# 6.0               0.623053
# 7.0               0.484597
# 3.2               0.415369
# 2.0               0.369217
# 5.1               0.253836
# 1.5               0.230760
# 4.4W              0.126918
# 3.1               0.115380
# 2.0.1             0.080766
# 8.0               0.069228
# 7.1               0.034614
# 4.0.3 - 7.1.1     0.023076
# 1.0               0.023076
# 5.0 - 8.0         0.023076
# 2.2 - 7.1.1       0.011538
# 7.0 - 7.1.1       0.011538
# 5.0 - 7.1.1       0.011538
# 4.1 - 7.1.1       0.011538
# 5.0 - 6.0         0.011538
# Name: Android Ver, dtype: float64
# #################################################

# %%
sns.countplot(x=df["Type"])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df["Content Rating"])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features   ### numeric---plot a graph distributiion plot
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.kdeplot(df["Price"])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df["Reviews"])
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df["Rating"])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df["Reviews"])
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Density'>

# %%
plt.hist(df["Rating"])
# Out:
# (array([  17.,   18.,   39.,   73.,  132.,  439.,  833., 1493., 3450.,
#         1702.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Rating"])
plt.show()

# %%
df["App"].value_counts().plot.pie(y=df["App"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-d5342b1a2b51> in <module>
# ----> 1 df["App"].value_counts().plot.pie(y=df["App"])
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1526         ):
#    1527             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1528         return self(kind="pie", **kwargs)
#    1529
#    1530     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1545             else:
#    1546                 blabels = None
# -> 1547             results = ax.pie(y, labels=blabels, **kwds)
#    1548
#    1549             if kwds.get("autopct", None) is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3072             w.set(**wedgeprops)
#    3073             slices.append(w)
# -> 3074             self.add_patch(w)
#    3075
#    3076             if shadow:
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2030         self._set_artist_props(p)
#    2031         if p.get_clip_path() is None:
# -> 2032             p.set_clip_path(self.patch)
#    2033         self._update_patch_limits(p)
#    2034         self.patches.append(p)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     752             if isinstance(path, Rectangle):
#     753                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 754                                                path.get_transform())
#     755                 self._clippath = None
#     756                 success = True
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     258     def get_transform(self):
#     259         """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 260         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     261
#     262     def get_data_transform(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     790
#     791     def get_patch_transform(self):
# --> 792         self._update_patch_transform()
#     793         return self._rect_transform
#     794
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     771         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     772         rot_trans = transforms.Affine2D()
# --> 773         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     774         self._rect_transform = transforms.BboxTransformTo(bbox)
#     775         self._rect_transform += rot_trans
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    1965         # Cast to float to avoid wraparound issues with uint8's
#    1966         x, y = float(x), float(y)
# -> 1967         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1968
#    1969     def translate(self, tx, ty):
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg(self, degrees)
#    1943         and :meth:`scale`.
#    1944         """
# -> 1945         return self.rotate(math.radians(degrees))
#    1946
#    1947     def rotate_around(self, x, y, theta):
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in rotate(self, theta)
#    1931         rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    1932                               float)
# -> 1933         self._mtx = np.dot(rotate_mtx, self._mtx)
#    1934         self.invalidate()
#    1935         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x00000134514428B0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2193                         self.figure.draw(renderer)
#    2194
# -> 2195                     bbox_inches = self.figure.get_tightbbox(
#    2196                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2197                     if pad_inches is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2504
#    2505         for a in artists:
# -> 2506             bbox = a.get_tightbbox(renderer)
#    2507             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2508                 bb.append(bbox)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4200                     # this artist
#    4201                     continue
# -> 4202             bbox = a.get_tightbbox(renderer)
#    4203             if (bbox is not None
#    4204                     and 0 < bbox.width < np.inf
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     276             The enclosing bounding box (in figure pixel coordinates).
#     277         """
# --> 278         bbox = self.get_window_extent(renderer)
#     279         if self.get_clip_on():
#     280             clip_box = self.get_clip_box()
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     236         flags = get_hinting_flag()
#     237         font = self._get_agg_font(prop)
# --> 238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#     240         d = font.get_descent()
#
# KeyboardInterrupt:

# %%
df["Category"].value_counts().plot.pie(y=df["Category"])
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
df["Category"].value_counts().plot.pie(y=df["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c39c4c7dae3f> in <module>
#       1 plt.figure(figsize=(15,6))
# ----> 2 sns.barplot(x=df_cat, y ='Count',data = category[:10],palette='hls')
#       3 plt.title('Top 10 App categories')
#       4 plt.xticks(rotation=90)
#       5 plt.show()
#
# NameError: name 'df_cat' is not defined

# %%
df[["Category","Installs"]]
# Out:
#                   Category  Installs
# 0           ART_AND_DESIGN     10000
# 1           ART_AND_DESIGN    500000
# 2           ART_AND_DESIGN   5000000
# 3           ART_AND_DESIGN  50000000
# 4           ART_AND_DESIGN    100000
# ...                    ...       ...
# 10835               FAMILY      5000
# 10836               FAMILY       100
# 10837              MEDICAL      1000
# 10838  BOOKS_AND_REFERENCE      1000
# 10839            LIFESTYLE  10000000
#
# [9659 rows x 2 columns]

# %%
df_cat_installs=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df2=df_cat_installs.head(10)

# %%
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# 1  Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2               Art & Design   2018-08-01               1.2.4      4.0.3
# 3               Art & Design   2018-06-08  Varies with device        4.2
# 4    Art & Design;Creativity   2018-06-20                 1.1        4.4
#
#    day  month  year
# 0    7      1  2018
# 1   15      1  2018
# 2    1      8  2018
# 3    8      6  2018
# 4   20      6  2018

# %%
dfa=df.groupby(["Category","App"])["Installs"].sum().reset_index()

# %%
dfa.sort_values("Installs",ascending=False)
# Out:
#                 Category                            App    Installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9275    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 6020             MEDICAL                   EP Cook Book           0
# 3662             FINANCE                    Eu sou Rico           0
# 1797              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 6471  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa[dfa.Category=="GAME"][:10]
# Out:
#      Category                              App   Installs
# 3960     GAME  1LINE – One Line with One Touch   10000000
# 3961     GAME      2-Player Co-op Zombie Shoot       1000
# 3962     GAME                           211:CK         10
# 3963     GAME                      211:CK Lite         10
# 3964     GAME                       4 in a Row     500000
# 3965     GAME                       4 in a row    5000000
# 3966     GAME                   4x4 Jeep Racer    1000000
# 3967     GAME   5 Nights at Cube Pizzeria City     100000
# 3968     GAME   7 Nights at Pixel Pizzeria - 2    1000000
# 3969     GAME                      8 Ball Pool  100000000

# %%
dfa[dfa.Category=="PRODUCTIVITY"][:10]
# Out:
#           Category                                              App  Installs
# 7231  PRODUCTIVITY              2Do - Reminders, To-do List & Notes    100000
# 7232  PRODUCTIVITY                   7 Weeks - Habit & Goal Tracker    500000
# 7233  PRODUCTIVITY                                    A-Z App Store    500000
# 7234  PRODUCTIVITY  ACCDB MDB DB Manager Pro - Editor for MS Access       500
# 7235  PRODUCTIVITY                                ACCEPT CE MARKING        10
# 7236  PRODUCTIVITY                                         AI Sight      1000
# 7237  PRODUCTIVITY                                AL Voice Recorder   1000000
# 7238  PRODUCTIVITY                      ALL-IN-ONE PACKAGE TRACKING   1000000
# 7239  PRODUCTIVITY                                   AP ENPS Mobile      5000
# 7240  PRODUCTIVITY           APUS Booster - Space Cleaner & Booster  10000000

# %%
dfa[dfa.Category=="FAMILY"][:10]
# Out:
#      Category                                                App  Installs
# 1671   FAMILY                      10 Minutes a Day Times Tables    100000
# 1672   FAMILY                               100 Doors of Revenge  10000000
# 1673   FAMILY                                    100+ C Programs      5000
# 1674   FAMILY                         101 C Programming Problems     50000
# 1675   FAMILY                   2048 BTS J Hope KPop Puzzle Game      1000
# 1676   FAMILY                                           2048(AI)      1000
# 1677   FAMILY  25 Mins Ako ay may lobo Etc Pinoy Kid Song Off...        10
# 1678   FAMILY  30WPM Amateur ham radio Koch CW Morse code tra...        10
# 1679   FAMILY                     3D Color by Number with Voxels    500000
# 1680   FAMILY   3D Color by Number: Voxel, Unicorn, Pixel Art 3D    100000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %%
rating=df.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating=df.groupby(["App"])["Rating"].mean().sort_values(ascending=False).reset_index()

# %%
rating[rating.Rating==5.0]
# Out:
#                                                   App  Rating
# 0                                       The CJ Rubric     5.0
# 1            Super Hearing Secret Voices Recorder PRO     5.0
# 2                                     Wifi BT Scanner     5.0
# 3                          Beacon Baptist Jupiter, FL     5.0
# 4                                       Story Time FD     5.0
# ..                                                ...     ...
# 266                            Quran Khmer Offline AY     5.0
# 267  AI Today : Artificial Intelligence News & AI 101     5.0
# 268                             Noticias FC Barcelona     5.0
# 269   Anatomy & Physiology Vocabulary Exam Review App     5.0
# 270                                            AJ Cam     5.0
#
# [271 rows x 2 columns]

# %%
rating2 = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0            FINANCE       100
# 1             FAMILY       100
# 2             FAMILY       100
# 3             FAMILY       100
# 4             FAMILY        50
# ...              ...       ...
# 9654           TOOLS        10
# 9655           TOOLS        10
# 9656           TOOLS        10
# 9657           TOOLS        10
# 9658  ART_AND_DESIGN         0
#
#                                                  App  Rating
# 0                                                 CF     5.0
# 1                                        CN Resident     5.0
# 2                                BV Sridhara Maharaj     5.0
# 3                                    BK Video Status     5.0
# 4                                          daskal.eu     5.0
# ...                                              ...     ...
# 9654  BT Position Sender - Bluetooth Position Sender     0.0
# 9655                                 BS TRACK CLIENT     0.0
# 9656                          BS Match Maker Premium     0.0
# 9657                                        BG-FLEET     0.0
# 9658                          Test Application DT 02     0.0
#
# [9659 rows x 4 columns]

# %%
df.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# 19  MAPS_AND_NAVIGATION    503281890   17729148
# 20              MEDICAL     38193177    1182971
# 21   NEWS_AND_MAGAZINES   2369217760   23130228
# 22            PARENTING     31521110     958331
# 23      PERSONALIZATION   1532494782   53543080
# 24          PHOTOGRAPHY   4649147655  105351270
# 25         PRODUCTIVITY   5793091369   55590649
# 26             SHOPPING   1400348785   44551730
# 27               SOCIAL   5487867902  227927801
# 28               SPORTS   1096474498   35348813
# 29                TOOLS   8001771915  229356578
# 30     TRAVEL_AND_LOCAL   2894887146   26819741
# 31        VIDEO_PLAYERS   3926902720   67484568
# 32              WEATHER    361100520   12295164

# %%
df.groupby(["Category","App"])["Reviews"].sum().sort_values(ascending=False).reset_index()
# Out:
#                 Category                                       App   Reviews
# 0                 SOCIAL                                  Facebook  78158306
# 1          COMMUNICATION                        WhatsApp Messenger  69119316
# 2                 SOCIAL                                 Instagram  66577313
# 3          COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 4                   GAME                            Clash of Clans  44891723
# ...                  ...                                       ...       ...
# 9654            BUSINESS                               CX Elevated         0
# 9655            BUSINESS                           CX Carrier Lite         0
# 9656              FAMILY    Ako ay may lobo Pinoy Kid Song Offline         0
# 9657  HEALTH_AND_FITNESS                                 CK Active         0
# 9658               TOOLS                                 AX Window         0
#
# [9659 rows x 3 columns]

# %%
df.groupby("Category").agg({"App":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category                                                App  \
# 0        ART_AND_DESIGN  Photo Editor & Candy Camera & Grid & ScrapBook...
# 1     AUTO_AND_VEHICLES  Monster Truck Stunt 3D 2019Real Tractor Farmin...
# 2                BEAUTY  Hush - Beauty for Everyoneipsy: Makeup, Beauty...
# 3   BOOKS_AND_REFERENCE  Wattpad 📖 Free BooksE-Book Read - Read Book fo...
# 4              BUSINESS  Visual Voicemail by MetroPCSIndeed Job SearchU...
# 5                COMICS  LINE WEBTOON - Free ComicsManga Master - Best ...
# 6         COMMUNICATION  Messenger – Text and Video Chat for FreeWhatsA...
# 7                DATING  Moco+ - Chat, Meet PeopleCalculatorTruth or Da...
# 8             EDUCATION  Duolingo: Learn Languages FreeTEDEnglish Commu...
# 9         ENTERTAINMENT  NetflixComplete Spanish MoviesPluto TV - It’s ...
# 10               EVENTS  All Events in CityTicketmaster Event TicketsRe...
# 11               FAMILY  Jewels Crush- Match 3 PuzzleColoring & LearnMa...
# 12              FINANCE  K PLUSING BankingCitibanamex MovilThe postal b...
# 13       FOOD_AND_DRINK  McDonald'sEasy and Fast RecipesCookpad - FREE ...
# 14                 GAME  ROBLOXSubway SurfersCandy Crush SagaSolitaireB...
# 15   HEALTH_AND_FITNESS  Home Workout - No EquipmentStep Counter - Calo...
# 16       HOUSE_AND_HOME  Zillow: Find Houses for Sale & Apartments for ...
# 17   LIBRARIES_AND_DEMO  Public Digital LibraryQuotesBest New Ringtones...
# 18            LIFESTYLE  Dollhouse Decorating GamesmetroZONEEasy Hair S...
# 19  MAPS_AND_NAVIGATION  Waze - GPS, Maps, Traffic Alerts & Live Naviga...
# 20              MEDICAL  Monash Uni Low FODMAP DietiBP Blood PressurePe...
# 21   NEWS_AND_MAGAZINES  Fox News – Breaking News, Live Video & News Al...
# 22            PARENTING  Baby NamesMy baby PianoZoo For Preschool Kids ...
# 23      PERSONALIZATION  Nova LauncherFunny RingtonesZEDGE™ Ringtones &...
# 24          PHOTOGRAPHY  TouchNote: Cards & GiftsShutterfly: Free Print...
# 25         PRODUCTIVITY  Microsoft WordAll-In-One Toolbox: Cleaner, Boo...
# 26             SHOPPING  Amazon for TabletsWish - Shopping Made FunOffe...
# 27               SOCIAL  FacebookInstagramFacebook LiteMessages, Text a...
# 28               SPORTS  ESPNFree Sports TVLiveScore: Live Sport Update...
# 29                TOOLS  Moto File ManagerGoogleGoogle TranslateMoto Di...
# 30     TRAVEL_AND_LOCAL  Expedia Hotels, Flights & Car Rental Travel De...
# 31        VIDEO_PLAYERS  YouTubeAll Video Downloader 2018Video Download...
# 32              WEATHER  The Weather Channel: Rain Forecast & Storm Ale...
#
#       Reviews
# 0     1419203
# 1     1163666
# 2      396240
# 3    16721314
# 4     9890245
# 5     2342071
# 6   285811368
# 7     3623544
# 8    13364148
# 9    34762650
# 10     161018
# 11  143825488
# 12   12662106
# 13    6325028
# 14  622298709
# 15   21361355
# 16    1929847
# 17     906831
# 18   11832671
# 19   17729148
# 20    1182971
# 21   23130228
# 22     958331
# 23   53543080
# 24  105351270
# 25   55590649
# 26   44551730
# 27  227927801
# 28   35348813
# 29  229356578
# 30   26819741
# 31   67484568
# 32   12295164

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
plt.figure(figsize=(10,15))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
df.groupby("Category").agg({"Size":"sum"}).reset_index()
# Out:
#                Category        Size
# 0        ART_AND_DESIGN    767000.0
# 1     AUTO_AND_VEHICLES   1502786.0
# 2                BEAUTY    648400.0
# 3   BOOKS_AND_REFERENCE   2548132.0
# 4              BUSINESS   5204075.0
# 5                COMICS    675953.0
# 6         COMMUNICATION   2736398.0
# 7                DATING   2480128.0
# 8             EDUCATION   1696082.0
# 9         ENTERTAINMENT   1474800.0
# 10               EVENTS    795934.0
# 11               FAMILY  46926467.0
# 12              FINANCE   5193070.0
# 13       FOOD_AND_DRINK   1803500.0
# 14                 GAME  36549550.0
# 15   HEALTH_AND_FITNESS   4795372.0
# 16       HOUSE_AND_HOME    990156.0
# 17   LIBRARIES_AND_DEMO    867325.0
# 18            LIFESTYLE   4948212.0
# 19  MAPS_AND_NAVIGATION   1751389.0
# 20              MEDICAL   7051709.0
# 21   NEWS_AND_MAGAZINES   2506508.0
# 22            PARENTING   1215700.0
# 23      PERSONALIZATION   3939843.0
# 24          PHOTOGRAPHY   3467897.0
# 25         PRODUCTIVITY   3571689.0
# 26             SHOPPING   2602561.0
# 27               SOCIAL   3020993.0
# 28               SPORTS   6836653.0
# 29                TOOLS   6420254.0
# 30     TRAVEL_AND_LOCAL   4177373.0
# 31        VIDEO_PLAYERS   2005680.0
# 32              WEATHER    710082.0

# %%
plt.figure(figsize=(15,15))
sns.barplot("Category","Size",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot("Rating",data=df,palette="Set1_r")
plt.xticks(rotation=90)
plt.title('Countplot for ratings')
plt.show()

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=df['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='Rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
