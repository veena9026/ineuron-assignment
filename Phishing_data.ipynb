# %% [markdown]
# ## importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ### Loading and reading file

# %%
data=pd.read_csv("https://raw.githubusercontent.com/veena9026/EDA_assignment/main/Training%20Dataset.csv")

# %%
data.head()
# Out:
#    id  having_IP_Address  URL_Length  Shortining_Service  having_At_Symbol  \
# 0   1                 -1           1                   1                 1
# 1   2                  1           1                   1                 1
# 2   3                  1           0                   1                 1
# 3   4                  1           0                   1                 1
# 4   5                  1           0                  -1                 1
#
#    double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# 0                        -1             -1                 -1              -1
# 1                         1             -1                  0               1
# 2                         1             -1                 -1              -1
# 3                         1             -1                 -1              -1
# 4                         1             -1                  1               1
#
# ...

# %%
data.describe()
# Out:
#                  id  having_IP_Address    URL_Length  Shortining_Service  \
# count  11055.000000       11055.000000  11055.000000        11055.000000
# mean    5528.000000           0.313795     -0.633198            0.738761
# std     3191.447947           0.949534      0.766095            0.673998
# min        1.000000          -1.000000     -1.000000           -1.000000
# 25%     2764.500000          -1.000000     -1.000000            1.000000
# 50%     5528.000000           1.000000     -1.000000            1.000000
# 75%     8291.500000           1.000000     -1.000000            1.000000
# max    11055.000000           1.000000      1.000000            1.000000
#
#        having_At_Symbol  double_slash_redirecting  Prefix_Suffix  \
# count      11055.000000              11055.000000   11055.000000
# mean           0.700588                  0.741474      -0.734962
# std            0.713598                  0.671011       0.678139
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11055 entries, 0 to 11054
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           11055 non-null  int64
#  1   having_IP_Address            11055 non-null  int64
#  2   URL_Length                   11055 non-null  int64
#  3   Shortining_Service           11055 non-null  int64
#  4   having_At_Symbol             11055 non-null  int64
#  5   double_slash_redirecting     11055 non-null  int64
#  6   Prefix_Suffix                11055 non-null  int64
#  7   having_Sub_Domain            11055 non-null  int64
#  8   SSLfinal_State               11055 non-null  int64
#  9   Domain_registeration_length  11055 non-null  int64
#  10  Favicon                      11055 non-null  int64
#  11  port                         11055 non-null  int64
#  12  HTTPS_token                  11055 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['id', 'having_IP_Address', 'URL_Length', 'Shortining_Service',
#        'having_At_Symbol', 'double_slash_redirecting', 'Prefix_Suffix',
#        'having_Sub_Domain', 'SSLfinal_State', 'Domain_registeration_length',
#        'Favicon', 'port', 'HTTPS_token', 'Request_URL', 'URL_of_Anchor',
#        'Links_in_tags', 'SFH', 'Submitting_to_email', 'Abnormal_URL',
#        'Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe',
#        'age_of_domain', 'DNSRecord', 'web_traffic', 'Page_Rank',
#        'Google_Index', 'Links_pointing_to_page', 'Statistical_report',
#        'Result'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                             0
# having_IP_Address              0
# URL_Length                     0
# Shortining_Service             0
# having_At_Symbol               0
# double_slash_redirecting       0
# Prefix_Suffix                  0
# having_Sub_Domain              0
# SSLfinal_State                 0
# Domain_registeration_length    0
# Favicon                        0
# port                           0
# HTTPS_token                    0
# Request_URL                    0
# URL_of_Anchor                  0
# Links_in_tags                  0
# SFH                            0
# Submitting_to_email            0
# Abnormal_URL                   0
# Redirect                       0
# on_mouseover                   0
# RightClick                     0
# popUpWidnow                    0
# Iframe                         0
# age_of_domain                  0
# DNSRecord                      0
# web_traffic                    0
# Page_Rank                      0
# ...

# %%
## check duplicates
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, having_IP_Address, URL_Length, Shortining_Service, having_At_Symbol, double_slash_redirecting, Prefix_Suffix, having_Sub_Domain, SSLfinal_State, Domain_registeration_length, Favicon, port, HTTPS_token, Request_URL, URL_of_Anchor, Links_in_tags, SFH, Submitting_to_email, Abnormal_URL, Redirect, on_mouseover, RightClick, popUpWidnow, Iframe, age_of_domain, DNSRecord, web_traffic, Page_Rank, Google_Index, Links_pointing_to_page, Statistical_report, Result]
# Index: []
#
# [0 rows x 32 columns]

# %%
for feature in data.columns:
    
    print(f"{feature}: {data[feature].value_counts()}")
# Out:
# id: 2047     1
# 7449     1
# 9510     1
# 3363     1
# 1314     1
#         ..
# 613      1
# 2660     1
# 8801     1
# 10848    1
# 2049     1
# Name: id, Length: 11055, dtype: int64
# having_IP_Address:  1    7262
# -1    3793
# Name: having_IP_Address, dtype: int64
# URL_Length: -1    8960
#  1    1960
#  0     135
# Name: URL_Length, dtype: int64
# Shortining_Service:  1    9611
# -1    1444
# Name: Shortining_Service, dtype: int64
# having_At_Symbol:  1    9400
# -1    1655
# Name: having_At_Symbol, dtype: int64
# double_slash_redirecting:  1    9626
# -1    1429
# Name: double_slash_redirecting, dtype: int64
# Prefix_Suffix: -1    9590
#  1    1465
# Name: Prefix_Suffix, dtype: int64
# having_Sub_Domain:  1    4070
#  0    3622
# -1    3363
# Name: having_Sub_Domain, dtype: int64
# SSLfinal_State:  1    6331
# -1    3557
#  0    1167
# Name: SSLfinal_State, dtype: int64
# Domain_registeration_length: -1    7389
#  1    3666
# Name: Domain_registeration_length, dtype: int64
# ...

# %% [markdown]
# ## EDA

# %%
df=data.copy()

# %%
df.head()
# Out:
#    id  having_IP_Address  URL_Length  Shortining_Service  having_At_Symbol  \
# 0   1                 -1           1                   1                 1
# 1   2                  1           1                   1                 1
# 2   3                  1           0                   1                 1
# 3   4                  1           0                   1                 1
# 4   5                  1           0                  -1                 1
#
#    double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# 0                        -1             -1                 -1              -1
# 1                         1             -1                  0               1
# 2                         1             -1                 -1              -1
# 3                         1             -1                 -1              -1
# 4                         1             -1                  1               1
#
# ...

# %%
df.groupby(["Page_Rank"])["Google_Index"].value_counts().plot.pie(figsize=(8,8),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Google_Index'>

# %%
sns.barplot(x="popUpWidnow",y="Google_Index",data=df,hue="Result")
# Out:
# <AxesSubplot:xlabel='popUpWidnow', ylabel='Google_Index'>

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="having_IP_Address",y="URL_Length",hue="Result",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="URL_Length",hue="Result",data=df)
# Out:
# <AxesSubplot:xlabel='URL_Length', ylabel='count'>

# %%
fig,axs=plt.subplots(1,4,figsize=(25,25))
plt.subplot(411)
sns.countplot(data=df,x="Shortining_Service",hue="Result",palette="pastel")
plt.subplot(412)
sns.countplot(data=df,x="having_At_Symbol",hue="Result",palette="ch:.25")
plt.subplot(413)
sns.countplot(data=df,x="double_slash_redirecting",hue="Result",palette="flare")
plt.subplot(414)
sns.countplot(data=df,x="Domain_registeration_length",hue="Result",palette="Set2")
# Out:
# <AxesSubplot:xlabel='Domain_registeration_length', ylabel='count'>

# %%
for i in df.columns:
    label_size=dict(df[i].value_counts())
    label=list(label_size.keys())
    size=list(label_size.values())
    plt.pie(size,labels=label,autopct="%1.1f%%")
    plt.title(f"Result vs {i}")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
